# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51589/RL/blob/main/practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A - Machine Initialization

machines = ['A', 'B', 'C']
M = 3
N_play = 10
epsilon = 0.2

# Part B - Initialize N, R and Q

N = [0, 0, 0]
R = [0, 0, 0]
Q = [0.0, 0.0, 0.0]

total_reward = 0

# Part C, D and E
# ε-Greedy Decision, Reward and Q Update

for play in range(1, N_play + 1):
    r = random.random()
    if r < epsilon:
        selected_index = random.randint(0, M - 1)
        decision = "Exploration"
    else:
        max_q = max(Q)
        best_machines = [
            i for i in range(M)
            if Q[i] == max_q
        ]
        selected_index = random.choice(best_machines)
        decision = "Exploitation"
    selected_machine = machines[selected_index]
    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Play with machine", selected_machine)

    # Part D - Reward Collection

    reward = float(input("Enter reward: "))

    # Part E - Update N, R and Q

    N[selected_index] += 1
    R[selected_index] += reward
    Q[selected_index] = (
        Q[selected_index]
        + (1 / N[selected_index])
        * (reward - Q[selected_index])
    )
    total_reward += reward
    print("Updated Q-value:",
          round(Q[selected_index], 4))

# Part F - Display Final Results

print("\n====================================")
print("FINAL RESULTS")
print("====================================")
print("\nMachine\tN\tR\tQ")
for i in range(M):
    print(
        machines[i],
        "\t",
        N[i],
        "\t",
        R[i],
        "\t",
        round(Q[i], 2)
    )
print("\nTotal reward after 10 plays:",
      total_reward)
# Out:
# Play 1
# Random number: 0.0328
# Decision: Exploration
# Play with machine B
# Enter reward: 65
# Updated Q-value: 65.0
#
# Play 2
# Random number: 0.821
# Decision: Exploitation
# Play with machine B
# Enter reward: 70
# Updated Q-value: 67.5
#
# Play 3
# Random number: 0.284
# Decision: Exploitation
# Play with machine B
# Enter reward: 80
# Updated Q-value: 71.6667
#
# Play 4
# Random number: 0.0887
# Decision: Exploration
# Play with machine B
# Enter reward: 90
# Updated Q-value: 76.25
#
# Play 5
# Random number: 0.2002
# Decision: Exploitation
# Play with machine B
# Enter reward: 65
# Updated Q-value: 74.0
#
# Play 6
# Random number: 0.279
# Decision: Exploitation
# Play with machine B
# Enter reward: 78
# Updated Q-value: 74.6667
#
# Play 7
# Random number: 0.1755
# Decision: Exploration
# Play with machine A
# Enter reward: 73
# Updated Q-value: 73.0
#
# Play 8
# Random number: 0.2673
# Decision: Exploitation
# Play with machine B
# Enter reward: 67
# Updated Q-value: 73.5714
#
# Play 9
# Random number: 0.2446
# Decision: Exploitation
# Play with machine B
# Enter reward: 89
# Updated Q-value: 75.5
#
# Play 10
# Random number: 0.3404
# Decision: Exploitation
# Play with machine B
# Enter reward: 98
# Updated Q-value: 78.0
#
# ====================================
# FINAL RESULTS
# ====================================
#
# Machine	N	R	Q
# A 	 1 	 73.0 	 73.0
# B 	 9 	 702.0 	 78.0
# C 	 0 	 0 	 0.0
#
# Total reward after 10 plays: 775.0
